# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import tensorflow_datasets as tfds
from tensorflow import keras
from keras import layers

# %%
data_train = tfds.load("deep_weeds", with_info=False, split='train[20%:100%]').take(800)#.filter(lambda x: x['label'] != 8).take(800)
data_valid  = tfds.load("deep_weeds", with_info=False, split='train[0%:20%]').take(200)#.filter(lambda x: x['label'] != 8).take(160)

# %%
import math

def preprocess(dict):
  processed_image = dict['image'] / 255
  processed_label = dict['label']
  return processed_image, processed_label

# Use the batch method to prepare batches.
train_ds = (data_train
                .map(preprocess)
                .cache()
                # .map(augment, num_parallel_calls=tf.data.experimental.AUTOTUNE)
                .batch(32)
                .prefetch(tf.data.experimental.AUTOTUNE))

valid_ds = data_valid.map(preprocess).cache().batch(32)

# %% [markdown]
# ## A residual network with 5 ResBlocks

# %%
from tensorflow import keras
from tensorflow.keras import layers

def make_model(input_shape, num_classes):
    inputs = keras.Input(shape=input_shape)
    x = inputs

    # Entry block
    x = layers.Conv2D(32, 3, strides=2, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    x = layers.Conv2D(64, 3, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    previous_block_activation = x  # Set aside residual

    # for size in [64, 128]:
    for size in [64, 64, 128, 128, 512]:
        x = layers.Activation("relu")(x)
        x = layers.SeparableConv2D(size, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.Activation("relu")(x)
        x = layers.SeparableConv2D(size, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.MaxPooling2D(3, strides=2, padding="same")(x)

        # Project residual
        residual = layers.Conv2D(size, 1, strides=2, padding="same")(
            previous_block_activation
        )
        x = layers.add([x, residual])  # Add back residual
        previous_block_activation = x  # Set aside next residual

    x = layers.SeparableConv2D(1024, 3, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    x = layers.GlobalAveragePooling2D()(x)
    if num_classes == 2:
        activation = "sigmoid"
        units = 1
    else:
        activation = "softmax"
        units = num_classes

    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(units, activation=activation)(x)
    return keras.Model(inputs, outputs)

model = make_model(input_shape=(256,256,3), num_classes=9)

model.compile(
    optimizer=keras.optimizers.Adam(0.001),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)

# %%
log = model.fit(
    train_ds, epochs=50, validation_data=valid_ds,
)
# Out:
# Epoch 1/50
# 25/25 [==============================] - 11s 270ms/step - loss: 1.6538 - accuracy: 0.4812 - val_loss: 2.1028 - val_accuracy: 0.5400
# Epoch 2/50
# 25/25 [==============================] - 6s 239ms/step - loss: 1.2700 - accuracy: 0.5775 - val_loss: 2.0325 - val_accuracy: 0.5400
# Epoch 3/50
# 25/25 [==============================] - 6s 239ms/step - loss: 1.0555 - accuracy: 0.6400 - val_loss: 1.9464 - val_accuracy: 0.5400
# Epoch 4/50
# 25/25 [==============================] - 6s 238ms/step - loss: 0.7807 - accuracy: 0.7237 - val_loss: 1.8485 - val_accuracy: 0.5400
# Epoch 5/50
# 25/25 [==============================] - 6s 240ms/step - loss: 0.4666 - accuracy: 0.8600 - val_loss: 1.7454 - val_accuracy: 0.5400
# Epoch 6/50
# 25/25 [==============================] - 6s 241ms/step - loss: 0.3682 - accuracy: 0.8813 - val_loss: 1.7045 - val_accuracy: 0.5400
# Epoch 7/50
# 25/25 [==============================] - 6s 240ms/step - loss: 0.2803 - accuracy: 0.9075 - val_loss: 1.6668 - val_accuracy: 0.5400
# Epoch 8/50
# 25/25 [==============================] - 6s 240ms/step - loss: 0.1537 - accuracy: 0.9550 - val_loss: 1.7049 - val_accuracy: 0.5400
# Epoch 9/50
# 25/25 [==============================] - 6s 238ms/step - loss: 0.1414 - accuracy: 0.9575 - val_loss: 1.7843 - val_accuracy: 0.5400
# Epoch 10/50
# 25/25 [==============================] - 6s 244ms/step - loss: 0.0922 - accuracy: 0.9700 - val_loss: 1.8523 - val_accuracy: 0.5400
# Epoch 11/50
# 25/25 [==============================] - 6s 237ms/step - loss: 0.0572 - accuracy: 0.9862 - val_loss: 2.2258 - val_accuracy: 0.5400
# Epoch 12/50
# 25/25 [==============================] - 6s 239ms/step - loss: 0.0343 - accuracy: 0.9937 - val_loss: 2.3839 - val_accuracy: 0.5400
# Epoch 13/50
# 25/25 [==============================] - 6s 238ms/step - loss: 0.0279 - accuracy: 0.9950 - val_loss: 2.8238 - val_accuracy: 0.5400
# Epoch 14/50
# 25/25 [==============================] - 6s 238ms/step - loss: 0.0187 - accuracy: 0.9975 - val_loss: 2.8454 - val_accuracy: 0.5400
# Epoch 15/50
# 25/25 [==============================] - 6s 241ms/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 3.3107 - val_accuracy: 0.5400
# Epoch 16/50
# 25/25 [==============================] - 6s 235ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 3.7678 - val_accuracy: 0.5400
# Epoch 17/50
# 25/25 [==============================] - 6s 235ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 4.0171 - val_accuracy: 0.5400
# Epoch 18/50
# 25/25 [==============================] - 6s 236ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 4.1953 - val_accuracy: 0.5400
# Epoch 19/50
# 25/25 [==============================] - 6s 236ms/step - loss: 9.8117e-04 - accuracy: 1.0000 - val_loss: 4.3083 - val_accuracy: 0.5400
# Epoch 20/50
# 25/25 [==============================] - 6s 246ms/step - loss: 7.1524e-04 - accuracy: 1.0000 - val_loss: 4.3529 - val_accuracy: 0.5400
# Epoch 21/50
# 25/25 [==============================] - 6s 241ms/step - loss: 7.6986e-04 - accuracy: 1.0000 - val_loss: 4.3624 - val_accuracy: 0.5400
# Epoch 22/50
# 25/25 [==============================] - 6s 237ms/step - loss: 5.6465e-04 - accuracy: 1.0000 - val_loss: 4.2666 - val_accuracy: 0.5400
# Epoch 23/50
# 25/25 [==============================] - 6s 239ms/step - loss: 4.9221e-04 - accuracy: 1.0000 - val_loss: 4.0772 - val_accuracy: 0.5400
# Epoch 24/50
# 25/25 [==============================] - 6s 239ms/step - loss: 4.4388e-04 - accuracy: 1.0000 - val_loss: 3.8307 - val_accuracy: 0.5450
# Epoch 25/50
# 25/25 [==============================] - 6s 240ms/step - loss: 3.8789e-04 - accuracy: 1.0000 - val_loss: 3.5161 - val_accuracy: 0.5350
# Epoch 26/50
# 25/25 [==============================] - 6s 236ms/step - loss: 4.4642e-04 - accuracy: 1.0000 - val_loss: 3.2919 - val_accuracy: 0.5400
# Epoch 27/50
# 25/25 [==============================] - 6s 235ms/step - loss: 3.1185e-04 - accuracy: 1.0000 - val_loss: 3.0297 - val_accuracy: 0.5450
# Epoch 28/50
# 25/25 [==============================] - 6s 236ms/step - loss: 3.2974e-04 - accuracy: 1.0000 - val_loss: 2.8046 - val_accuracy: 0.5500
# Epoch 29/50
# 25/25 [==============================] - 6s 236ms/step - loss: 2.9387e-04 - accuracy: 1.0000 - val_loss: 2.6321 - val_accuracy: 0.5450
# Epoch 30/50
# 25/25 [==============================] - 6s 237ms/step - loss: 2.8555e-04 - accuracy: 1.0000 - val_loss: 2.5026 - val_accuracy: 0.5500
# Epoch 31/50
# 25/25 [==============================] - 6s 236ms/step - loss: 2.6750e-04 - accuracy: 1.0000 - val_loss: 2.4052 - val_accuracy: 0.5550
# Epoch 32/50
# 25/25 [==============================] - 6s 239ms/step - loss: 2.4067e-04 - accuracy: 1.0000 - val_loss: 2.3383 - val_accuracy: 0.5600
# Epoch 33/50
# 25/25 [==============================] - 6s 241ms/step - loss: 2.3077e-04 - accuracy: 1.0000 - val_loss: 2.2821 - val_accuracy: 0.5700
# Epoch 34/50
# 25/25 [==============================] - 6s 237ms/step - loss: 2.3436e-04 - accuracy: 1.0000 - val_loss: 2.2361 - val_accuracy: 0.5800
# Epoch 35/50
# 25/25 [==============================] - 6s 237ms/step - loss: 2.1741e-04 - accuracy: 1.0000 - val_loss: 2.2081 - val_accuracy: 0.5850
# Epoch 36/50
# 25/25 [==============================] - 6s 238ms/step - loss: 2.0304e-04 - accuracy: 1.0000 - val_loss: 2.1973 - val_accuracy: 0.5850
# Epoch 37/50
# 25/25 [==============================] - 6s 239ms/step - loss: 2.0069e-04 - accuracy: 1.0000 - val_loss: 2.1946 - val_accuracy: 0.5850
# Epoch 38/50
# 25/25 [==============================] - 6s 242ms/step - loss: 1.8702e-04 - accuracy: 1.0000 - val_loss: 2.1965 - val_accuracy: 0.5900
# Epoch 39/50
# 25/25 [==============================] - 6s 241ms/step - loss: 1.9777e-04 - accuracy: 1.0000 - val_loss: 2.1956 - val_accuracy: 0.5950
# Epoch 40/50
# 25/25 [==============================] - 6s 241ms/step - loss: 1.6411e-04 - accuracy: 1.0000 - val_loss: 2.1885 - val_accuracy: 0.5950
# Epoch 41/50
# 25/25 [==============================] - 6s 237ms/step - loss: 1.5425e-04 - accuracy: 1.0000 - val_loss: 2.1777 - val_accuracy: 0.5950
# Epoch 42/50
# 25/25 [==============================] - 6s 236ms/step - loss: 1.6398e-04 - accuracy: 1.0000 - val_loss: 2.1684 - val_accuracy: 0.5950
# Epoch 43/50
# 25/25 [==============================] - 6s 238ms/step - loss: 1.4802e-04 - accuracy: 1.0000 - val_loss: 2.1714 - val_accuracy: 0.5950
# Epoch 44/50
# 25/25 [==============================] - 6s 240ms/step - loss: 1.5121e-04 - accuracy: 1.0000 - val_loss: 2.1786 - val_accuracy: 0.6000
# Epoch 45/50
# 25/25 [==============================] - 6s 238ms/step - loss: 1.5828e-04 - accuracy: 1.0000 - val_loss: 2.1796 - val_accuracy: 0.6000
# Epoch 46/50
# 25/25 [==============================] - 6s 238ms/step - loss: 1.3922e-04 - accuracy: 1.0000 - val_loss: 2.1771 - val_accuracy: 0.5950
# Epoch 47/50
# 25/25 [==============================] - 6s 238ms/step - loss: 1.4047e-04 - accuracy: 1.0000 - val_loss: 2.1810 - val_accuracy: 0.5950
# Epoch 48/50
# 25/25 [==============================] - 6s 238ms/step - loss: 1.3323e-04 - accuracy: 1.0000 - val_loss: 2.1887 - val_accuracy: 0.6000
# Epoch 49/50
# 25/25 [==============================] - 6s 242ms/step - loss: 1.3046e-04 - accuracy: 1.0000 - val_loss: 2.1831 - val_accuracy: 0.5950
# Epoch 50/50
# 25/25 [==============================] - 6s 239ms/step - loss: 1.2425e-04 - accuracy: 1.0000 - val_loss: 2.1822 - val_accuracy: 0.5950

# %%
plt.plot(log.history['accuracy'])
plt.plot(log.history['val_accuracy'])
plt.title('model accuracy: 5 ResBlocks')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

plt.plot(log.history['loss'])
plt.plot(log.history['val_loss'])
plt.title('model loss: 5 ResBlocks')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %% [markdown]
# ## Data augmentation?

# %%
data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.1),
    ]
)

# Use the batch method to prepare batches.
augmented_train_ds = (data_train
                .map(preprocess)
                .cache()
                .map(lambda x, y: (data_augmentation(x, training=True), y))
                .batch(32)
                .prefetch(tf.data.experimental.AUTOTUNE))

# %%
# reiniialize the model

model = make_model(input_shape=(256,256,3), num_classes=9)

model.compile(
    optimizer=keras.optimizers.Adam(0.001),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)

log_augmented = model.fit(
    augmented_train_ds, epochs=50, validation_data=valid_ds,
)
# Out:
# Epoch 1/50
# 25/25 [==============================] - 11s 394ms/step - loss: 1.5819 - accuracy: 0.5025 - val_loss: 2.1030 - val_accuracy: 0.5400
# Epoch 2/50
# 25/25 [==============================] - 10s 394ms/step - loss: 1.4572 - accuracy: 0.5275 - val_loss: 2.0437 - val_accuracy: 0.5400
# Epoch 3/50
# 25/25 [==============================] - 10s 393ms/step - loss: 1.3774 - accuracy: 0.5475 - val_loss: 1.9629 - val_accuracy: 0.5400
# Epoch 4/50
# 25/25 [==============================] - 10s 395ms/step - loss: 1.2944 - accuracy: 0.5600 - val_loss: 1.9143 - val_accuracy: 0.5400
# Epoch 5/50
# 25/25 [==============================] - 10s 398ms/step - loss: 1.2868 - accuracy: 0.5713 - val_loss: 1.8436 - val_accuracy: 0.5400
# Epoch 6/50
# 20/25 [=======================>......] - ETA: 1s - loss: 1.2481 - accuracy: 0.5828

# %%
plt.plot(log_augmented.history['accuracy'])
plt.plot(log_augmented.history['val_accuracy'])
plt.title('model accuracy: 5 ResBlocks')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

plt.plot(range(15,50),log_augmented.history['loss'][15:])
plt.plot(range(15,50),log_augmented.history['val_loss'][15:])
plt.title('model loss: 5 ResBlocks')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %% [markdown]
# ## A simpler model?
